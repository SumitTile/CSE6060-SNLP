# %% [markdown]
# ###  LOR 1

# %%
import nltk

#doc1 = """I am pleased to recommend MrXX for an MS in Computer Science at your esteemed university. I have known him since his second year. He was my student in the 3rd semester (2nd year), where I taught him the course of Database Management Systems. 
#I first got to know X in the course of Database Management Systems, CSE-2004. In the first week of the course, I was surprised to know that X, an Electronics and Instrumentation student, had taken up a computer science core course. Initially I was doubtful about a non-CS student’s approach and grasp of the subject, but he adapted to it as naturally as a fish to water. By the time the course came to an end, he had proved his mettle. 
#I observed that X had a keen interest and was fully involved in the course when I saw his performances during the Lab sessions, where he would be able to grasp new concepts such as query formation and joins. He has been highly active in the technical scene of our college too with him organizing many events.
#As a part of the course, students are required to develop a project, with a fully functional Database System consisting of the concepts learnt throughout the semester. Despite X not being from a computer science background, his project did not languish. He went above and beyond to make a professional database design, which included an ‘Auto-Increment’ feature using a PL/SQL sequence written by him, bulk insertion into the table and other features.
#I was pleased to know that he applied the concepts in his internship extensively to build a professional tool for Intellect Design Arena. He designed this tool to make the process of configuring a Logical Data Model easier and much faster. It consisted of a User Interface (UI) that can replicate back-end tasks such as inserting data in a database at the click of a button. His task was cut out for him as the tool was being built for J.P. Morgan Chase as a client and hence there was no room for error. I am proud to say that the tool, which he built over a course of two months, was pushed to production at the end of his internship.
#X makes a strong candidate for your Master's program majoring in Computer Science. His proposed candidature has my endorsement without any reservations whatsoever. 
#"""

# %%
myfile = open("chunktask.txt")            #...Importing an text file
doc1 = myfile.read()
doc1
# Out:
# "YouTube is an American online video-sharing platform headquartered in San Bruno, California. Three former PayPal employeesâ€”Chad Hurley, \nSteve Chen, and Jawed Karimâ€”created the service in February 2005. Google bought the site in November 2006 for US$1.65 billion; YouTube now\n operates as one of Google's subsidiaries.\n\nYouTube allows users to upload, view, rate, share, add to playlists, report, comment on videos, and subscribe to other users. It offers a\n wide variety of user-generated and corporate media videos. Available content includes video clips, TV show clips, music videos, short and \ndocumentary films, audio recordings, movie trailers, live streams, and other content such as video blogging, short original videos, and \neducational videos. Most content on YouTube is uploaded by individuals, but media corporations including CBS, the BBC, Vevo, and Hulu \noffer some of their material via YouTube as part of the YouTube partnership program. Unregistered users can only watch (but not upload) \nvideos on the site, while registered users are also permitted to upload an unlimited number of videos and add comments to videos. Videos \nthat are age-restricted are available only to registered users affirming themselves to be at least 18 years old."

# %%
token = nltk.word_tokenize(doc1)

# %%
postags = nltk.pos_tag(token)
print(postags)
# Out:
# [('YouTube', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('American', 'JJ'), ('online', 'NN'), ('video-sharing', 'JJ'), ('platform', 'NN'), ('headquartered', 'VBN'), ('in', 'IN'), ('San', 'NNP'), ('Bruno', 'NNP'), (',', ','), ('California', 'NNP'), ('.', '.'), ('Three', 'CD'), ('former', 'JJ'), ('PayPal', 'NNP'), ('employeesâ€', 'NN'), ('”', 'NNP'), ('Chad', 'NNP'), ('Hurley', 'NNP'), (',', ','), ('Steve', 'NNP'), ('Chen', 'NNP'), (',', ','), ('and', 'CC'), ('Jawed', 'NNP'), ('Karimâ€', 'NNP'), ('”', 'NNP'), ('created', 'VBD'), ('the', 'DT'), ('service', 'NN'), ('in', 'IN'), ('February', 'NNP'), ('2005', 'CD'), ('.', '.'), ('Google', 'NNP'), ('bought', 'VBD'), ('the', 'DT'), ('site', 'NN'), ('in', 'IN'), ('November', 'NNP'), ('2006', 'CD'), ('for', 'IN'), ('US', 'NNP'), ('$', '$'), ('1.65', 'CD'), ('billion', 'CD'), (';', ':'), ('YouTube', 'NNP'), ('now', 'RB'), ('operates', 'VBZ'), ('as', 'IN'), ('one', 'CD'), ('of', 'IN'), ('Google', 'NNP'), ("'s", 'POS'), ('subsidiaries', 'NNS'), ('.', '.'), ('YouTube', 'NNP'), ('allows', 'VBZ'), ('users', 'NNS'), ('to', 'TO'), ('upload', 'VB'), (',', ','), ('view', 'NN'), (',', ','), ('rate', 'NN'), (',', ','), ('share', 'NN'), (',', ','), ('add', 'VB'), ('to', 'TO'), ('playlists', 'NNS'), (',', ','), ('report', 'NN'), (',', ','), ('comment', 'NN'), ('on', 'IN'), ('videos', 'NNS'), (',', ','), ('and', 'CC'), ('subscribe', 'NN'), ('to', 'TO'), ('other', 'JJ'), ('users', 'NNS'), ('.', '.'), ('It', 'PRP'), ('offers', 'VBZ'), ('a', 'DT'), ('wide', 'JJ'), ('variety', 'NN'), ('of', 'IN'), ('user-generated', 'JJ'), ('and', 'CC'), ('corporate', 'JJ'), ('media', 'NNS'), ('videos', 'NN'), ('.', '.'), ('Available', 'JJ'), ('content', 'NN'), ('includes', 'VBZ'), ('video', 'JJ'), ('clips', 'NNS'), (',', ','), ('TV', 'NN'), ('show', 'NN'), ('clips', 'NNS'), (',', ','), ('music', 'NN'), ('videos', 'NN'), (',', ','), ('short', 'JJ'), ('and', 'CC'), ('documentary', 'JJ'), ('films', 'NNS'), (',', ','), ('audio', 'JJ'), ('recordings', 'NNS'), (',', ','), ('movie', 'NN'), ('trailers', 'NNS'), (',', ','), ('live', 'JJ'), ('streams', 'NN'), (',', ','), ('and', 'CC'), ('other', 'JJ'), ('content', 'NN'), ('such', 'JJ'), ('as', 'IN'), ('video', 'NN'), ('blogging', 'NN'), (',', ','), ('short', 'JJ'), ('original', 'JJ'), ('videos', 'NNS'), (',', ','), ('and', 'CC'), ('educational', 'JJ'), ('videos', 'NNS'), ('.', '.'), ('Most', 'JJS'), ('content', 'JJ'), ('on', 'IN'), ('YouTube', 'NNP'), ('is', 'VBZ'), ('uploaded', 'VBN'), ('by', 'IN'), ('individuals', 'NNS'), (',', ','), ('but', 'CC'), ('media', 'NNS'), ('corporations', 'NNS'), ('including', 'VBG'), ('CBS', 'NNP'), (',', ','), ('the', 'DT'), ('BBC', 'NNP'), (',', ','), ('Vevo', 'NNP'), (',', ','), ('and', 'CC'), ('Hulu', 'NNP'), ('offer', 'VBP'), ('some', 'DT'), ('of', 'IN'), ('their', 'PRP$'), ('material', 'NN'), ('via', 'IN'), ('YouTube', 'NNP'), ('as', 'IN'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('YouTube', 'NNP'), ('partnership', 'NN'), ('program', 'NN'), ('.', '.'), ('Unregistered', 'JJ'), ('users', 'NNS'), ('can', 'MD'), ('only', 'RB'), ('watch', 'VB'), ('(', '('), ('but', 'CC'), ('not', 'RB'), ('upload', 'JJ'), (')', ')'), ('videos', 'NN'), ('on', 'IN'), ('the', 'DT'), ('site', 'NN'), (',', ','), ('while', 'IN'), ('registered', 'VBN'), ('users', 'NNS'), ('are', 'VBP'), ('also', 'RB'), ('permitted', 'VBN'), ('to', 'TO'), ('upload', 'VB'), ('an', 'DT'), ('unlimited', 'JJ'), ('number', 'NN'), ('of', 'IN'), ('videos', 'NNS'), ('and', 'CC'), ('add', 'VB'), ('comments', 'NNS'), ('to', 'TO'), ('videos', 'NNS'), ('.', '.'), ('Videos', 'NNP'), ('that', 'WDT'), ('are', 'VBP'), ('age-restricted', 'JJ'), ('are', 'VBP'), ('available', 'JJ'), ('only', 'RB'), ('to', 'TO'), ('registered', 'VB'), ('users', 'NNS'), ('affirming', 'VBG'), ('themselves', 'PRP'), ('to', 'TO'), ('be', 'VB'), ('at', 'IN'), ('least', 'JJS'), ('18', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('.', '.')]

# %%
grammar1 = "VP: {<RB.?>*<VB.?>*<NNP>+<NN>?}"
cp1 = nltk.RegexpParser(grammar1)

# %%
result = cp1.parse(postags)

# %%
print(result)
# Out:
# (S
#   YouTube/NN
#   is/VBZ
#   an/DT
#   American/JJ
#   online/NN
#   video-sharing/JJ
#   platform/NN
#   headquartered/VBN
#   in/IN
#   (VP San/NNP Bruno/NNP)
#   ,/,
#   (VP California/NNP)
#   ./.
#   Three/CD
#   former/JJ
#   (VP PayPal/NNP employeesâ€/NN)
#   (VP ”/NNP Chad/NNP Hurley/NNP)
#   ,/,
#   (VP Steve/NNP Chen/NNP)
#   ,/,
#   and/CC
#   (VP Jawed/NNP Karimâ€/NNP ”/NNP)
#   created/VBD
#   the/DT
#   service/NN
#   in/IN
#   (VP February/NNP)
#   2005/CD
#   ./.
#   (VP Google/NNP)
#   bought/VBD
#   the/DT
#   site/NN
#   in/IN
#   (VP November/NNP)
#   2006/CD
#   for/IN
#   (VP US/NNP)
#   $/$
#   1.65/CD
#   billion/CD
#   ;/:
#   (VP YouTube/NNP)
#   now/RB
#   operates/VBZ
#   as/IN
#   one/CD
#   of/IN
#   (VP Google/NNP)
#   's/POS
#   subsidiaries/NNS
#   ./.
#   (VP YouTube/NNP)
#   allows/VBZ
#   users/NNS
#   to/TO
#   upload/VB
#   ,/,
#   view/NN
#   ,/,
#   rate/NN
#   ,/,
#   share/NN
#   ,/,
#   add/VB
#   to/TO
#   playlists/NNS
#   ,/,
#   report/NN
#   ,/,
#   comment/NN
#   on/IN
#   videos/NNS
#   ,/,
#   and/CC
#   subscribe/NN
#   to/TO
#   other/JJ
#   users/NNS
#   ./.
#   It/PRP
#   offers/VBZ
#   a/DT
#   wide/JJ
#   variety/NN
#   of/IN
#   user-generated/JJ
#   and/CC
#   corporate/JJ
#   media/NNS
#   videos/NN
#   ./.
#   Available/JJ
#   content/NN
#   includes/VBZ
#   video/JJ
#   clips/NNS
#   ,/,
#   TV/NN
#   show/NN
#   clips/NNS
#   ,/,
#   music/NN
#   videos/NN
#   ,/,
#   short/JJ
#   and/CC
#   documentary/JJ
#   films/NNS
#   ,/,
#   audio/JJ
#   recordings/NNS
#   ,/,
#   movie/NN
#   trailers/NNS
#   ,/,
#   live/JJ
#   streams/NN
#   ,/,
#   and/CC
#   other/JJ
#   content/NN
#   such/JJ
#   as/IN
#   video/NN
#   blogging/NN
#   ,/,
#   short/JJ
#   original/JJ
#   videos/NNS
#   ,/,
#   and/CC
#   educational/JJ
#   videos/NNS
#   ./.
#   Most/JJS
#   content/JJ
#   on/IN
#   (VP YouTube/NNP)
#   is/VBZ
#   uploaded/VBN
#   by/IN
#   individuals/NNS
#   ,/,
#   but/CC
#   media/NNS
#   corporations/NNS
#   (VP including/VBG CBS/NNP)
#   ,/,
#   the/DT
#   (VP BBC/NNP)
#   ,/,
#   (VP Vevo/NNP)
#   ,/,
#   and/CC
#   (VP Hulu/NNP)
#   offer/VBP
#   some/DT
#   of/IN
#   their/PRP$
#   material/NN
#   via/IN
#   (VP YouTube/NNP)
#   as/IN
#   part/NN
#   of/IN
#   the/DT
#   (VP YouTube/NNP partnership/NN)
#   program/NN
#   ./.
#   Unregistered/JJ
#   users/NNS
#   can/MD
#   only/RB
#   watch/VB
#   (/(
#   but/CC
#   not/RB
#   upload/JJ
#   )/)
#   videos/NN
#   on/IN
#   the/DT
#   site/NN
#   ,/,
#   while/IN
#   registered/VBN
#   users/NNS
#   are/VBP
#   also/RB
#   permitted/VBN
#   to/TO
#   upload/VB
#   an/DT
#   unlimited/JJ
#   number/NN
#   of/IN
#   videos/NNS
#   and/CC
#   add/VB
#   comments/NNS
#   to/TO
#   videos/NNS
#   ./.
#   (VP Videos/NNP)
#   that/WDT
#   are/VBP
#   age-restricted/JJ
#   are/VBP
#   available/JJ
#   only/RB
#   to/TO
#   registered/VB
#   users/NNS
#   affirming/VBG
#   themselves/PRP
#   to/TO
#   be/VB
#   at/IN
#   least/JJS
#   18/CD
#   years/NNS
#   old/JJ
#   ./.)

# %%
result.draw()

# %%
chunks1 = nltk.ne_chunk(postags)

# %%
print(chunks1)
# Out:
# (S
#   (ORGANIZATION YouTube/NN)
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   online/NN
#   video-sharing/JJ
#   platform/NN
#   headquartered/VBN
#   in/IN
#   (GPE San/NNP Bruno/NNP)
#   ,/,
#   (GPE California/NNP)
#   ./.
#   Three/CD
#   former/JJ
#   (ORGANIZATION PayPal/NNP)
#   employeesâ€/NN
#   ”/NNP
#   Chad/NNP
#   (PERSON Hurley/NNP)
#   ,/,
#   (PERSON Steve/NNP Chen/NNP)
#   ,/,
#   and/CC
#   (PERSON Jawed/NNP)
#   Karimâ€/NNP
#   ”/NNP
#   created/VBD
#   the/DT
#   service/NN
#   in/IN
#   February/NNP
#   2005/CD
#   ./.
#   (PERSON Google/NNP)
#   bought/VBD
#   the/DT
#   site/NN
#   in/IN
#   November/NNP
#   2006/CD
#   for/IN
#   (GSP US/NNP)
#   $/$
#   1.65/CD
#   billion/CD
#   ;/:
#   (ORGANIZATION YouTube/NNP)
#   now/RB
#   operates/VBZ
#   as/IN
#   one/CD
#   of/IN
#   (GPE Google/NNP)
#   's/POS
#   subsidiaries/NNS
#   ./.
#   (ORGANIZATION YouTube/NNP)
#   allows/VBZ
#   users/NNS
#   to/TO
#   upload/VB
#   ,/,
#   view/NN
#   ,/,
#   rate/NN
#   ,/,
#   share/NN
#   ,/,
#   add/VB
#   to/TO
#   playlists/NNS
#   ,/,
#   report/NN
#   ,/,
#   comment/NN
#   on/IN
#   videos/NNS
#   ,/,
#   and/CC
#   subscribe/NN
#   to/TO
#   other/JJ
#   users/NNS
#   ./.
#   It/PRP
#   offers/VBZ
#   a/DT
#   wide/JJ
#   variety/NN
#   of/IN
#   user-generated/JJ
#   and/CC
#   corporate/JJ
#   media/NNS
#   videos/NN
#   ./.
#   Available/JJ
#   content/NN
#   includes/VBZ
#   video/JJ
#   clips/NNS
#   ,/,
#   TV/NN
#   show/NN
#   clips/NNS
#   ,/,
#   music/NN
#   videos/NN
#   ,/,
#   short/JJ
#   and/CC
#   documentary/JJ
#   films/NNS
#   ,/,
#   audio/JJ
#   recordings/NNS
#   ,/,
#   movie/NN
#   trailers/NNS
#   ,/,
#   live/JJ
#   streams/NN
#   ,/,
#   and/CC
#   other/JJ
#   content/NN
#   such/JJ
#   as/IN
#   video/NN
#   blogging/NN
#   ,/,
#   short/JJ
#   original/JJ
#   videos/NNS
#   ,/,
#   and/CC
#   educational/JJ
#   videos/NNS
#   ./.
#   Most/JJS
#   content/JJ
#   on/IN
#   (ORGANIZATION YouTube/NNP)
#   is/VBZ
#   uploaded/VBN
#   by/IN
#   individuals/NNS
#   ,/,
#   but/CC
#   media/NNS
#   corporations/NNS
#   including/VBG
#   (ORGANIZATION CBS/NNP)
#   ,/,
#   the/DT
#   (ORGANIZATION BBC/NNP)
#   ,/,
#   (GPE Vevo/NNP)
#   ,/,
#   and/CC
#   Hulu/NNP
#   offer/VBP
#   some/DT
#   of/IN
#   their/PRP$
#   material/NN
#   via/IN
#   (ORGANIZATION YouTube/NNP)
#   as/IN
#   part/NN
#   of/IN
#   the/DT
#   (ORGANIZATION YouTube/NNP)
#   partnership/NN
#   program/NN
#   ./.
#   Unregistered/JJ
#   users/NNS
#   can/MD
#   only/RB
#   watch/VB
#   (/(
#   but/CC
#   not/RB
#   upload/JJ
#   )/)
#   videos/NN
#   on/IN
#   the/DT
#   site/NN
#   ,/,
#   while/IN
#   registered/VBN
#   users/NNS
#   are/VBP
#   also/RB
#   permitted/VBN
#   to/TO
#   upload/VB
#   an/DT
#   unlimited/JJ
#   number/NN
#   of/IN
#   videos/NNS
#   and/CC
#   add/VB
#   comments/NNS
#   to/TO
#   videos/NNS
#   ./.
#   (PERSON Videos/NNP)
#   that/WDT
#   are/VBP
#   age-restricted/JJ
#   are/VBP
#   available/JJ
#   only/RB
#   to/TO
#   registered/VB
#   users/NNS
#   affirming/VBG
#   themselves/PRP
#   to/TO
#   be/VB
#   at/IN
#   least/JJS
#   18/CD
#   years/NNS
#   old/JJ
#   ./.)

# %%
chunks1.draw()

# %% [markdown]
# ### LOR 2

# %%
myfile = open("chunktask2.txt")            #...Importing an text file
doc2 = myfile.read()
doc2
# Out:
# "Space Exploration Technologies Corp., trading as SpaceX, is an American aerospace manufacturer and space transportation services company\n headquartered in Hawthorne, California. It was founded in 2002 by Elon Musk with the goal of reducing space transportation costs to\n enable the colonization of Mars. SpaceX has developed several launch vehicles, the Starlink satellite constellation, and \nthe Dragon spacecraft.\n\nSpaceX's achievements include the first privately funded liquid-propellant rocket to reach orbit (Falcon 1 in 2008), the first\n private company to successfully launch, orbit, and recover a spacecraft (Dragon in 2010), the first private company to send a spacecraft\n to the International Space Station (Dragon in 2012), the first propulsive landing for an orbital rocket (Falcon 9 in 2015), the \nfirst reuse of an orbital rocket (Falcon 9 in 2017), the first private company to launch an object into orbit around the Sun (Falcon\n Heavy's payload of a Tesla Roadster in 2018), and the first private company to send astronauts to the International Space Station \n(Dragon 2 in 2020). SpaceX has flown 20[15] cargo resupply missions to the International Space Station (ISS) under a partnership \nwith NASA,[16] as well as an uncrewed demonstration flight of the human-rated Dragon 2 spacecraft (Crew Demo-1) on March 2, 2019, and \nthe first crewed Dragon 2 flight on May 30, 2020."

# %%
tokens = nltk.word_tokenize(doc2)

# %%
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Space', 'NNP'), ('Exploration', 'NNP'), ('Technologies', 'NNPS'), ('Corp.', 'NNP'), (',', ','), ('trading', 'NN'), ('as', 'IN'), ('SpaceX', 'NNP'), (',', ','), ('is', 'VBZ'), ('an', 'DT'), ('American', 'JJ'), ('aerospace', 'NN'), ('manufacturer', 'NN'), ('and', 'CC'), ('space', 'NN'), ('transportation', 'NN'), ('services', 'NNS'), ('company', 'NN'), ('headquartered', 'VBD'), ('in', 'IN'), ('Hawthorne', 'NNP'), (',', ','), ('California', 'NNP'), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('founded', 'VBN'), ('in', 'IN'), ('2002', 'CD'), ('by', 'IN'), ('Elon', 'NNP'), ('Musk', 'NNP'), ('with', 'IN'), ('the', 'DT'), ('goal', 'NN'), ('of', 'IN'), ('reducing', 'VBG'), ('space', 'NN'), ('transportation', 'NN'), ('costs', 'NNS'), ('to', 'TO'), ('enable', 'VB'), ('the', 'DT'), ('colonization', 'NN'), ('of', 'IN'), ('Mars', 'NNP'), ('.', '.'), ('SpaceX', 'NNP'), ('has', 'VBZ'), ('developed', 'VBN'), ('several', 'JJ'), ('launch', 'JJ'), ('vehicles', 'NNS'), (',', ','), ('the', 'DT'), ('Starlink', 'NNP'), ('satellite', 'NN'), ('constellation', 'NN'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('Dragon', 'NNP'), ('spacecraft', 'NN'), ('.', '.'), ('SpaceX', 'NNP'), ("'s", 'POS'), ('achievements', 'NNS'), ('include', 'VBP'), ('the', 'DT'), ('first', 'JJ'), ('privately', 'RB'), ('funded', 'VBN'), ('liquid-propellant', 'JJ'), ('rocket', 'NN'), ('to', 'TO'), ('reach', 'VB'), ('orbit', 'NN'), ('(', '('), ('Falcon', 'NNP'), ('1', 'CD'), ('in', 'IN'), ('2008', 'CD'), (')', ')'), (',', ','), ('the', 'DT'), ('first', 'JJ'), ('private', 'JJ'), ('company', 'NN'), ('to', 'TO'), ('successfully', 'RB'), ('launch', 'VB'), (',', ','), ('orbit', 'NN'), (',', ','), ('and', 'CC'), ('recover', 'VB'), ('a', 'DT'), ('spacecraft', 'NN'), ('(', '('), ('Dragon', 'NNP'), ('in', 'IN'), ('2010', 'CD'), (')', ')'), (',', ','), ('the', 'DT'), ('first', 'JJ'), ('private', 'JJ'), ('company', 'NN'), ('to', 'TO'), ('send', 'VB'), ('a', 'DT'), ('spacecraft', 'NN'), ('to', 'TO'), ('the', 'DT'), ('International', 'NNP'), ('Space', 'NNP'), ('Station', 'NNP'), ('(', '('), ('Dragon', 'NNP'), ('in', 'IN'), ('2012', 'CD'), (')', ')'), (',', ','), ('the', 'DT'), ('first', 'JJ'), ('propulsive', 'JJ'), ('landing', 'NN'), ('for', 'IN'), ('an', 'DT'), ('orbital', 'JJ'), ('rocket', 'NN'), ('(', '('), ('Falcon', 'NNP'), ('9', 'CD'), ('in', 'IN'), ('2015', 'CD'), (')', ')'), (',', ','), ('the', 'DT'), ('first', 'JJ'), ('reuse', 'NN'), ('of', 'IN'), ('an', 'DT'), ('orbital', 'JJ'), ('rocket', 'NN'), ('(', '('), ('Falcon', 'NNP'), ('9', 'CD'), ('in', 'IN'), ('2017', 'CD'), (')', ')'), (',', ','), ('the', 'DT'), ('first', 'JJ'), ('private', 'JJ'), ('company', 'NN'), ('to', 'TO'), ('launch', 'VB'), ('an', 'DT'), ('object', 'NN'), ('into', 'IN'), ('orbit', 'NN'), ('around', 'IN'), ('the', 'DT'), ('Sun', 'NNP'), ('(', '('), ('Falcon', 'NNP'), ('Heavy', 'NNP'), ("'s", 'POS'), ('payload', 'NN'), ('of', 'IN'), ('a', 'DT'), ('Tesla', 'NNP'), ('Roadster', 'NNP'), ('in', 'IN'), ('2018', 'CD'), (')', ')'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('first', 'JJ'), ('private', 'JJ'), ('company', 'NN'), ('to', 'TO'), ('send', 'VB'), ('astronauts', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('International', 'NNP'), ('Space', 'NNP'), ('Station', 'NNP'), ('(', '('), ('Dragon', 'NNP'), ('2', 'CD'), ('in', 'IN'), ('2020', 'CD'), (')', ')'), ('.', '.'), ('SpaceX', 'NNP'), ('has', 'VBZ'), ('flown', 'VBN'), ('20', 'CD'), ('[', 'JJ'), ('15', 'CD'), (']', 'JJ'), ('cargo', 'NN'), ('resupply', 'NN'), ('missions', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('International', 'NNP'), ('Space', 'NNP'), ('Station', 'NNP'), ('(', '('), ('ISS', 'NNP'), (')', ')'), ('under', 'IN'), ('a', 'DT'), ('partnership', 'NN'), ('with', 'IN'), ('NASA', 'NNP'), (',', ','), ('[', 'VBD'), ('16', 'CD'), (']', 'NN'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('an', 'DT'), ('uncrewed', 'JJ'), ('demonstration', 'NN'), ('flight', 'NN'), ('of', 'IN'), ('the', 'DT'), ('human-rated', 'JJ'), ('Dragon', 'NNP'), ('2', 'CD'), ('spacecraft', 'NN'), ('(', ' ...

# %%
grammar2 = "NN: {<DT.?><JJ?><.NN.>}"
cp2 = nltk.RegexpParser(grammar2)

# %%
result2 = cp2.parse(pos_tags)

# %%
print(result2)
# Out:
# (S
#   Space/NNP
#   Exploration/NNP
#   Technologies/NNPS
#   Corp./NNP
#   ,/,
#   trading/NN
#   as/IN
#   SpaceX/NNP
#   ,/,
#   is/VBZ
#   an/DT
#   American/JJ
#   aerospace/NN
#   manufacturer/NN
#   and/CC
#   space/NN
#   transportation/NN
#   services/NNS
#   company/NN
#   headquartered/VBD
#   in/IN
#   Hawthorne/NNP
#   ,/,
#   California/NNP
#   ./.
#   It/PRP
#   was/VBD
#   founded/VBN
#   in/IN
#   2002/CD
#   by/IN
#   Elon/NNP
#   Musk/NNP
#   with/IN
#   the/DT
#   goal/NN
#   of/IN
#   reducing/VBG
#   space/NN
#   transportation/NN
#   costs/NNS
#   to/TO
#   enable/VB
#   the/DT
#   colonization/NN
#   of/IN
#   Mars/NNP
#   ./.
#   SpaceX/NNP
#   has/VBZ
#   developed/VBN
#   several/JJ
#   launch/JJ
#   vehicles/NNS
#   ,/,
#   the/DT
#   Starlink/NNP
#   satellite/NN
#   constellation/NN
#   ,/,
#   and/CC
#   the/DT
#   Dragon/NNP
#   spacecraft/NN
#   ./.
#   SpaceX/NNP
#   's/POS
#   achievements/NNS
#   include/VBP
#   the/DT
#   first/JJ
#   privately/RB
#   funded/VBN
#   liquid-propellant/JJ
#   rocket/NN
#   to/TO
#   reach/VB
#   orbit/NN
#   (/(
#   Falcon/NNP
#   1/CD
#   in/IN
#   2008/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   successfully/RB
#   launch/VB
#   ,/,
#   orbit/NN
#   ,/,
#   and/CC
#   recover/VB
#   a/DT
#   spacecraft/NN
#   (/(
#   Dragon/NNP
#   in/IN
#   2010/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   send/VB
#   a/DT
#   spacecraft/NN
#   to/TO
#   the/DT
#   International/NNP
#   Space/NNP
#   Station/NNP
#   (/(
#   Dragon/NNP
#   in/IN
#   2012/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   propulsive/JJ
#   landing/NN
#   for/IN
#   an/DT
#   orbital/JJ
#   rocket/NN
#   (/(
#   Falcon/NNP
#   9/CD
#   in/IN
#   2015/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   reuse/NN
#   of/IN
#   an/DT
#   orbital/JJ
#   rocket/NN
#   (/(
#   Falcon/NNP
#   9/CD
#   in/IN
#   2017/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   launch/VB
#   an/DT
#   object/NN
#   into/IN
#   orbit/NN
#   around/IN
#   the/DT
#   Sun/NNP
#   (/(
#   Falcon/NNP
#   Heavy/NNP
#   's/POS
#   payload/NN
#   of/IN
#   a/DT
#   Tesla/NNP
#   Roadster/NNP
#   in/IN
#   2018/CD
#   )/)
#   ,/,
#   and/CC
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   send/VB
#   astronauts/NNS
#   to/TO
#   the/DT
#   International/NNP
#   Space/NNP
#   Station/NNP
#   (/(
#   Dragon/NNP
#   2/CD
#   in/IN
#   2020/CD
#   )/)
#   ./.
#   SpaceX/NNP
#   has/VBZ
#   flown/VBN
#   20/CD
#   [/JJ
#   15/CD
#   ]/JJ
#   cargo/NN
#   resupply/NN
#   missions/NNS
#   to/TO
#   the/DT
#   International/NNP
#   Space/NNP
#   Station/NNP
#   (/(
#   ISS/NNP
#   )/)
#   under/IN
#   a/DT
#   partnership/NN
#   with/IN
#   NASA/NNP
#   ,/,
#   [/VBD
#   16/CD
#   ]/NN
#   as/RB
#   well/RB
#   as/IN
#   an/DT
#   uncrewed/JJ
#   demonstration/NN
#   flight/NN
#   of/IN
#   the/DT
#   human-rated/JJ
#   Dragon/NNP
#   2/CD
#   spacecraft/NN
#   (/(
#   Crew/NNP
#   Demo-1/NNP
#   )/)
#   on/IN
#   March/NNP
#   2/CD
#   ,/,
#   2019/CD
#   ,/,
#   and/CC
#   the/DT
#   first/JJ
#   crewed/VBD
#   Dragon/NNP
#   2/CD
#   flight/NN
#   on/IN
#   May/NNP
#   30/CD
#   ,/,
#   2020/CD
#   ./.)

# %%
result2.draw()

# %%
chunks2 = nltk.ne_chunk(pos_tags)

# %%
print(chunks2)
# Out:
# (S
#   (PERSON Space/NNP)
#   (ORGANIZATION Exploration/NNP Technologies/NNPS Corp./NNP)
#   ,/,
#   trading/NN
#   as/IN
#   (ORGANIZATION SpaceX/NNP)
#   ,/,
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   aerospace/NN
#   manufacturer/NN
#   and/CC
#   space/NN
#   transportation/NN
#   services/NNS
#   company/NN
#   headquartered/VBD
#   in/IN
#   (GPE Hawthorne/NNP)
#   ,/,
#   (GPE California/NNP)
#   ./.
#   It/PRP
#   was/VBD
#   founded/VBN
#   in/IN
#   2002/CD
#   by/IN
#   (PERSON Elon/NNP Musk/NNP)
#   with/IN
#   the/DT
#   goal/NN
#   of/IN
#   reducing/VBG
#   space/NN
#   transportation/NN
#   costs/NNS
#   to/TO
#   enable/VB
#   the/DT
#   colonization/NN
#   of/IN
#   (PERSON Mars/NNP)
#   ./.
#   (ORGANIZATION SpaceX/NNP)
#   has/VBZ
#   developed/VBN
#   several/JJ
#   launch/JJ
#   vehicles/NNS
#   ,/,
#   the/DT
#   (ORGANIZATION Starlink/NNP)
#   satellite/NN
#   constellation/NN
#   ,/,
#   and/CC
#   the/DT
#   (GPE Dragon/NNP)
#   spacecraft/NN
#   ./.
#   (ORGANIZATION SpaceX/NNP)
#   's/POS
#   achievements/NNS
#   include/VBP
#   the/DT
#   first/JJ
#   privately/RB
#   funded/VBN
#   liquid-propellant/JJ
#   rocket/NN
#   to/TO
#   reach/VB
#   orbit/NN
#   (/(
#   Falcon/NNP
#   1/CD
#   in/IN
#   2008/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   successfully/RB
#   launch/VB
#   ,/,
#   orbit/NN
#   ,/,
#   and/CC
#   recover/VB
#   a/DT
#   spacecraft/NN
#   (/(
#   (ORGANIZATION Dragon/NNP)
#   in/IN
#   2010/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   send/VB
#   a/DT
#   spacecraft/NN
#   to/TO
#   the/DT
#   (ORGANIZATION International/NNP Space/NNP Station/NNP)
#   (/(
#   (ORGANIZATION Dragon/NNP)
#   in/IN
#   2012/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   propulsive/JJ
#   landing/NN
#   for/IN
#   an/DT
#   orbital/JJ
#   rocket/NN
#   (/(
#   Falcon/NNP
#   9/CD
#   in/IN
#   2015/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   reuse/NN
#   of/IN
#   an/DT
#   orbital/JJ
#   rocket/NN
#   (/(
#   Falcon/NNP
#   9/CD
#   in/IN
#   2017/CD
#   )/)
#   ,/,
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   launch/VB
#   an/DT
#   object/NN
#   into/IN
#   orbit/NN
#   around/IN
#   the/DT
#   (ORGANIZATION Sun/NNP)
#   (/(
#   (ORGANIZATION Falcon/NNP Heavy/NNP)
#   's/POS
#   payload/NN
#   of/IN
#   a/DT
#   Tesla/NNP
#   Roadster/NNP
#   in/IN
#   2018/CD
#   )/)
#   ,/,
#   and/CC
#   the/DT
#   first/JJ
#   private/JJ
#   company/NN
#   to/TO
#   send/VB
#   astronauts/NNS
#   to/TO
#   the/DT
#   (ORGANIZATION International/NNP Space/NNP Station/NNP)
#   (/(
#   (ORGANIZATION Dragon/NNP)
#   2/CD
#   in/IN
#   2020/CD
#   )/)
#   ./.
#   (ORGANIZATION SpaceX/NNP)
#   has/VBZ
#   flown/VBN
#   20/CD
#   [/JJ
#   15/CD
#   ]/JJ
#   cargo/NN
#   resupply/NN
#   missions/NNS
#   to/TO
#   the/DT
#   (ORGANIZATION International/NNP Space/NNP Station/NNP)
#   (/(
#   (ORGANIZATION ISS/NNP)
#   )/)
#   under/IN
#   a/DT
#   partnership/NN
#   with/IN
#   (ORGANIZATION NASA/NNP)
#   ,/,
#   [/VBD
#   16/CD
#   ]/NN
#   as/RB
#   well/RB
#   as/IN
#   an/DT
#   uncrewed/JJ
#   demonstration/NN
#   flight/NN
#   of/IN
#   the/DT
#   human-rated/JJ
#   Dragon/NNP
#   2/CD
#   spacecraft/NN
#   (/(
#   (ORGANIZATION Crew/NNP)
#   Demo-1/NNP
#   )/)
#   on/IN
#   March/NNP
#   2/CD
#   ,/,
#   2019/CD
#   ,/,
#   and/CC
#   the/DT
#   first/JJ
#   crewed/VBD
#   Dragon/NNP
#   2/CD
#   flight/NN
#   on/IN
#   May/NNP
#   30/CD
#   ,/,
#   2020/CD
#   ./.)

# %%
chunks2.draw()
